# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
def f(x):
    return (x-2)*(x+1)

def df(x):
    return 2*x-1 
dff1 = (f(x+h)-f(x-h))/2*h
dff2 = (f(x+h)-2*f(x)+f(x-h))/h**2

# %%
x= np.linspace(-1.5,2.5)
h = 0.1
x0 = 0.5

# %%
plt.plot(x,f(x))
plt.xlabel('x')
plt.ylabel('y')
plt.scatter(x,f(x),color='red')
plt.grid(True, linestyle = 'dashed')
plt.show()

# %%
plt.xlim([0,1])
plt.plot(x0,f(x0),'bo')
plt.plot(x,f(x))
plt.xlabel('x')
plt.ylabel('y')
plt.scatter(x,f(x),color='red')
plt.grid(True, linestyle = 'dashed')
plt.show()

# %%
x1= -0.5
plt.ylim([-1.5,-1])
plt.plot(x1,f(x1),'bo')
plt.plot(x,f(x))
plt.xlabel('x')
plt.ylabel('y')
plt.scatter(x,f(x),color='red')
plt.grid(True, linestyle = 'dashed')
plt.show()

# %%
x1= -0.5
plt.ylim([-1.5,-1])
plt.xlim([-1,0])
plt.plot(x1,f(x1),'bo')
plt.plot(x,f(x))
plt.xlabel('x')
plt.ylabel('y')
plt.scatter(x,f(x),color='red')
plt.grid(True, linestyle = 'dashed')
plt.show()

# %%
def f1(x):
    if x>0:
        return x
    elif x<0:
        return -x
    else:
        return 0

# %%
x= np.linspace(-1,1)
h = 0.1
x2 = 0.2

# %%
plt.plot(x,abs(x))
plt.plot(x2,abs(x2),'bo')
plt.xlabel('x')
plt.ylabel('y')
plt.scatter(x,abs(x),color='red')
plt.grid(True, linestyle = 'dashed')
plt.show()

# %%
plt.xlim([0,0.5])
plt.plot(x,abs(x))
plt.plot(x2,abs(x2),'bo')
plt.xlabel('x')
plt.ylabel('y')
plt.scatter(x,abs(x),color='red')
plt.grid(True, linestyle = 'dashed')
plt.show()

# %%
plt.ylim([0,0.4])
plt.xlim([0,0.5])
plt.plot(x,abs(x))
plt.plot(x2,abs(x2),'bo')
plt.xlabel('x')
plt.ylabel('y')
plt.scatter(x,abs(x),color='red')
plt.grid(True, linestyle = 'dashed')
plt.show()
